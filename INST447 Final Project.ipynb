# %% [markdown]
# # Development Trends in DC

# %% [markdown]
# ## Project Summary

# %% [markdown]
# ### Our goal with this project is to explore the trend of redevelopment and its outcomes in DC. We will do this by examining specific land use, areas undergoing redevelopment, and affordable units avabilable. This is important because we want to learn what land is being used for in DC, and if there are affordable units available. Our results will show the overall trends in the redevelopment in DC, and if there is afforable units within those areas being developed.

# %% [markdown]
# ## Data

# %% [markdown]
# ### All datasets are from Open Data DC. The first dataset is on existing land use in DC. It records the land used for now and what the land was used before. We decided to use this dataset to make a comparison and find out the interesting trend behind the redevelopment. The second dataset is on WDCEP (Washington DC Economic Partnership) redevelopement in DC. We decided to use this dataset to see the trends in development plans in DC. The last dataset we used was on affordable housing in DC. We chose this dataset to see the plans in affordable housing development and the amount of affordable units available.

# %% [markdown]
# ## Data Wrangling/Cleaning

# %% [markdown]
# ### Most cleaning revolved around dropping unnecessary columns/data, renaming many columns, and removing N/A values. Dataframes were created to hold certain columns of datasets. Aggregation was performed to get certain sums and counts.

# %% [markdown]
# ## Explore the Trend of Redevelopment
# #### Geting Trend from Existing Land Use in DC AREA
# #### Source data: https://opendata.dc.gov/datasets/existing-land-use?geometry=-78.003%2C38.707%2C-76.026%2C39.081
# #### Metadata page of source data: https://www.arcgis.com/sharing/rest/content/items/245179183eee41e08852ff9d5dbd3bcb/info/metadata/metadata.xml?format=default&output=html

# %% [markdown]
# ### Data Cleaning/Wrangling

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import data file
df = pd.read_csv("Existing_Land_Use.csv")
df
# Out:
# E:\anaconda\ana\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        OBJECTID OP_LAYER  CNT_OP_LAYER MIN_DXF_LAYER  AREAKM  AREAMILES  WAT  \
# 0             1      NaN             0           NaN     177         69    0
# 1             2      NaN             0           NaN     177         69    0
# 2             3      NaN             0           NaN     177         69    0
# 3             4      NaN             0           NaN     177         69    0
# 4             5      NaN             0           NaN     177         69    0
# ...         ...      ...           ...           ...     ...        ...  ...
# 55244     55245      NaN             0           NaN     177         69    0
# 55245     55246      NaN             0           NaN     177         69    0
# 55246     55247      NaN             0           NaN     177         69    0
# 55247     55248      NaN             0           NaN     177         69    0
# 55248     55249      NaN             0           NaN     177         69    0
#
#        WAT_ID  WAT_CODE WAT_NAME  ... GIS_ID SQR_NUM  LU_CODE QCFLAG  \
# 0           0         0      NaN  ...   3187    3187      MDR    nan
# 1           0         0      NaN  ...   3357    3357        C    nan
# 2           0         0      NaN  ...   3357    3357        C    nan
# 3           0         0      NaN  ...    NaN     NaN     TROW    nan
# 4           0         0      NaN  ...    NaN     NaN        R    nan
# ...       ...       ...      ...  ...    ...     ...      ...    ...
# 55244       0         0      NaN  ...   0454    0454       MU    nan
# 55245       0         0      NaN  ...   0376    0376        C    nan
# 55246       0         0      NaN  ...   0377    0377        C    nan
# 55247       0         0      NaN  ...   0227    0227       FP    nan
# 55248       0         0      NaN  ...   0227    0227       FP    nan
#
#       OLD_LU_CD ISVACANT  HASBLDG VACTYPE SHAPE_Length SHAPE_Area
# 0             C      NaN      NaN     NaN          322       4489
# 1             C      NaN      NaN     NaN          262       4207
# 2             C      NaN      NaN     NaN          210       2011
# 3             R      NaN      NaN     NaN          257        410
# 4             R      NaN      NaN     NaN         1427      49140
# ...         ...      ...      ...     ...          ...        ...
# 55244         C      NaN      NaN     NaN          406       6784
# 55245       NaN        y        y      VB          219       2522
# 55246         C        y        y      VB          166       1662
# 55247         O      NaN      NaN     NaN          374       8352
# 55248         O      NaN      NaN     NaN          733      28857
#
# [55249 rows x 23 columns]

# %%
# We only need Ward_ID, LU_CODE, OLD_LU_CD,SHAPE_Length,SHAPE_Area Columns
# Drop all the other columns
df1 = df.drop(columns=['OBJECTID', 'OP_LAYER','CNT_OP_LAYER','MIN_DXF_LAYER',\
                 'AREAKM','AREAMILES','WAT','WAT_ID','WAT_CODE','WAT_NAME',\
                 'DXF_LAYER','SQRSUF','GIS_ID','SQR_NUM','QCFLAG','ISVACANT',\
                'HASBLDG','VACTYPE'])

# Change Column name and code name in LU_CODE and OLD_LU_CODE
# For Easy understanding purpose
# For Easy observing purpose
df2 = df1.rename(columns={"LU_CODE": "Land_use_code", "OLD_LU_CD": "Old_Land_use_code"})
df2['Land_use_code'] = df2['Land_use_code'].replace(['LDR'],'Low Densit Residential')
df2['Land_use_code'] = df2['Land_use_code'].replace(['LMDR'],'Low-Medium Density Residential')
df2['Land_use_code'] = df2['Land_use_code'].replace(['MDR'],'Medium Density Residential')
df2['Land_use_code'] = df2['Land_use_code'].replace(['HDR'],'High Density Residential')
df2['Land_use_code'] = df2['Land_use_code'].replace(['GC','NC','C','O'],'Commercial')
df2['Land_use_code'] = df2['Land_use_code'].replace(['TCU'],'Transport, Communication, Utilities')
df2['Land_use_code'] = df2['Land_use_code'].replace(['HI','I','LI'],'Industrial')
df2['Land_use_code'] = df2['Land_use_code'].replace(['MU'],'Mixed Use')
df2['Land_use_code'] = df2['Land_use_code'].replace(['S'],'Institutional')
df2['Land_use_code'] = df2['Land_use_code'].replace(['FP'],'Federal Public')
df2['Land_use_code'] = df2['Land_use_code'].replace(['LP'],'Local Police')
df2['Land_use_code'] = df2['Land_use_code'].replace(['PQP-I'],'Public, Quasi-Public, Insitutional')
df2['Land_use_code'] = df2['Land_use_code'].replace(['R'],'Parks and Open Spaces')
df2['Land_use_code'] = df2['Land_use_code'].replace(['PARKING'],'Parking')
df2['Land_use_code'] = df2['Land_use_code'].replace(['ROADS'],'Roads')
df2['Land_use_code'] = df2['Land_use_code'].replace(['ALLEYS'],'Alleys')
df2['Land_use_code'] = df2['Land_use_code'].replace(['MEDIAN'],'Median')
df2['Land_use_code'] = df2['Land_use_code'].replace(['TROW'],'Transporation Right of Way')
df2['Land_use_code'] = df2['Land_use_code'].replace(['CANAL','RIVER','LAKE'],'Water')
df2['Land_use_code'] = df2['Land_use_code'].replace(np.nan,'Undetermined')

df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['LDR'],'Low Densit Residential')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['MDR'],'Medium Density Residential')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['LMDR'],'Low-Medium Density Residential')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['HDR'],'High Density Residential')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['GC','NC','C','O'],'Commercial')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['TCU'],'Transport, Communication, Utilities')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['HI','I','LI'],'Industrial')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['MU'],'Mixed Use')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['S'],'Institutional')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['FP'],'Federal Public')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['LP'],'Local Police')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['PQP-I'],'Public, Quasi-Public, Insitutional')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['R'],'Parks and Open Spaces')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['PARKING'],'Parking')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['ROADS'],'Roads')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['ALLEYS'],'Alleys')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['MEDIAN'],'Median')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['TROW'],'Transporation Right of Way')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['CANAL','RIVER','LAKE'],'Water')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(np.nan,'Undetermined')
df2['Old_Land_use_code'] = df2['Old_Land_use_code'].replace(['V','VB','VL'],'Undetermined')
df2
# Out:
#        WARD_ID               Land_use_code      Old_Land_use_code  \
# 0            4  Medium Density Residential             Commercial
# 1            4                  Commercial             Commercial
# 2            4                  Commercial             Commercial
# 3            0  Transporation Right of Way  Parks and Open Spaces
# 4            0       Parks and Open Spaces  Parks and Open Spaces
# ...        ...                         ...                    ...
# 55244        2                   Mixed Use             Commercial
# 55245        2                  Commercial           Undetermined
# 55246        2                  Commercial             Commercial
# 55247        2              Federal Public             Commercial
# 55248        2              Federal Public             Commercial
#
#        SHAPE_Length  SHAPE_Area
# 0               322        4489
# 1               262        4207
# 2               210        2011
# 3               257         410
# 4              1427       49140
# ...             ...         ...
# 55244           406        6784
# 55245           219        2522
# 55246           166        1662
# 55247           374        8352
# 55248           733       28857
#
# [55249 rows x 5 columns]

# %%
# Generate a .csv file of the cleaned Dataset
pd.DataFrame(df2).to_csv("Land_use_cleaned.csv", index=False)

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# ### 1: Given a overall comparison

# %%
# Given a overview of different facilities in land use 
print(df2['Land_use_code'].value_counts())
print('\n')
print(df2['Old_Land_use_code'].value_counts())
# Out:
# Transporation Right of Way             11182
# Alleys                                 10628
# Low-Medium Density Residential          8610
# Low Densit Residential                  7825
# Commercial                              4722
# Medium Density Residential              2477
# Parks and Open Spaces                   2327
# Median                                  1827
# Roads                                   1700
# Institutional                           1189
# High Density Residential                 422
# Federal Public                           372
# Local Police                             372
# Undetermined                             369
# Industrial                               360
# Water                                    331
# Transport, Communication, Utilities      293
# Public, Quasi-Public, Insitutional       139
# Mixed Use                                 50
# Parking                                   42
# TRAFFICIS                                 12
# Name: Land_use_code, dtype: int64
#
#
# Undetermined                           16357
# Alleys                                 10629
# Low-Medium Density Residential          7331
# Low Densit Residential                  5954
# Commercial                              3618
# Parks and Open Spaces                   2298
# Medium Density Residential              2231
# Public, Quasi-Public, Insitutional      1955
# Median                                  1826
# Roads                                   1696
# Transport, Communication, Utilities      340
# High Density Residential                 339
# Water                                    331
# Industrial                               286
# Transporation Right of Way                22
# Mixed Use                                 16
# TRAFFICIS                                 12
# Parking                                    8
# Name: Old_Land_use_code, dtype: int64

# %%
# Put them into a dataframe
df3 = df2['Land_use_code'].value_counts().rename_axis('Facilities').reset_index(name='Recent_LU_Counts')
df4 = df2['Old_Land_use_code'].value_counts().rename_axis('Facilities').reset_index(name='Old_LU_Counts')
LU_comparison = df3.merge(df4,how= 'outer')
LU_comparison['Old_LU_Counts'] = LU_comparison['Old_LU_Counts'].replace(np.nan,0)

# Export as .csv File
pd.DataFrame(LU_comparison).to_csv("LU_comparison.csv", index=False)
LU_comparison
# Out:
#                              Facilities  Recent_LU_Counts  Old_LU_Counts
# 0            Transporation Right of Way             11182             22
# 1                                Alleys             10628          10629
# 2        Low-Medium Density Residential              8610           7331
# 3                Low Densit Residential              7825           5954
# 4                            Commercial              4722           3618
# 5            Medium Density Residential              2477           2231
# 6                 Parks and Open Spaces              2327           2298
# 7                                Median              1827           1826
# 8                                 Roads              1700           1696
# 9                         Institutional              1189              0
# 10             High Density Residential               422            339
# 11                       Federal Public               372              0
# 12                         Local Police               372              0
# 13                         Undetermined               369          16357
# 14                           Industrial               360            286
# 15                                Water               331            331
# 16  Transport, Communication, Utilities               293            340
# 17   Public, Quasi-Public, Insitutional               139           1955
# 18                            Mixed Use                50             16
# 19                              Parking                42              8
# 20                            TRAFFICIS                12             12

# %% [markdown]
# #### By comparing the land use at different times, we find that the undetermined lands are decreasing and used for different purposes. Most of the facilities lands tend to increase, including residential lands, commercial lands, etc.

# %% [markdown]
# ### 2: Getting trend in different Wards

# %%
# Using the cleaned dataset 
# Getting dataframe of the current land use in different ward
df_p1 = df2.drop(columns = ['Old_Land_use_code','SHAPE_Length','SHAPE_Area'])

# Multiple Grouping and counting
ward_cur=df_p1.groupby(['WARD_ID','Land_use_code'],as_index = False)['Land_use_code'].agg({'Num_facilities':'count'})
print(ward_cur)
# Pivot the table, long to wide 
ward_cur = ward_cur.pivot_table(index=['Land_use_code'], 
                    columns='WARD_ID', 
                    values='Num_facilities')
ward_cur = ward_cur.fillna(0)
# Out:
#      WARD_ID                        Land_use_code  Num_facilities
# 0          0                               Alleys            7167
# 1          0                           Commercial              48
# 2          0                       Federal Public             195
# 3          0             High Density Residential               2
# 4          0                           Industrial              21
# ..       ...                                  ...             ...
# 169        8                                Roads             150
# 170        8           Transporation Right of Way              15
# 171        8  Transport, Communication, Utilities              20
# 172        8                         Undetermined              36
# 173        8                                Water              15
#
# [174 rows x 3 columns]

# %%
# Current land use in different Ward
pd.DataFrame(ward_cur).to_csv("ward_cur.csv", index=False)
ward_cur
# Out:
# WARD_ID                                 0   1    2    3    4    5    6    7  \
# Land_use_code
# Alleys                               7167 256  325  431  630  555  443  562
# Commercial                             48 568 1120  285  394  520  923  450
# Federal Public                        195   1   77   16   11    8   55    4
# High Density Residential                2 102  130   67   30   14   43   12
# Industrial                             21  26   29    1   17  155   89   15
# Institutional                          27 116  286  121  133  138  149  135
# Local Police                           32  41   70   28   30   30   70   37
# Low Densit Residential                 12 113  247 1672 1410  994  132 2544
# Low-Medium Density Residential          2 792  959  556 1141 1332 1309 1562
# Median                               1588   4   34   65   17   30   41   16
# Medium Density Residential             14 351  377  142  182  202  238  526
# Mixed Use                               0   7   25    5    2    0   10    0
# Parking                                 5   0   17    6    0    1   13    0
# Parks and Open Spaces                1245  72  218  149  107  103  178  164
# Public, Quasi-Public, Insitutional      7  20   14    3   24   22   17   16
# Roads                                 339  56  191  272  165  176  209  142
# TRAFFICIS                               8   0    0    0    0    0    4    0
# Transporation Right of Way          10957   3   26   43   28   19   20   14
# Transport, Communication, Utilities    58   5   20    6   43  111   20   10
# Undetermined                            0   3   46   64   33   38   42  107
# Water                                 199   1   38    9    3    7   19   40
#
# WARD_ID                               8
# Land_use_code
# Alleys                              259
# Commercial                          414
# Federal Public                        5
# High Density Residential             22
# Industrial                            7
# Institutional                        84
# Local Police                         34
# Low Densit Residential              701
# Low-Medium Density Residential      956
# Median                               32
# Medium Density Residential          445
# Mixed Use                             1
# Parking                               0
# Parks and Open Spaces                91
# Public, Quasi-Public, Insitutional   16
# Roads                               150
# TRAFFICIS                             0
# Transporation Right of Way           15
# Transport, Communication, Utilities  20
# Undetermined                         36
# Water                                15

# %%
# Getting dataframe of the past land use in different ward
df_p2 = df2.drop(columns = ['Land_use_code','SHAPE_Length','SHAPE_Area'])

# Multiple Grouping and counting
ward_past=df_p2.groupby(['WARD_ID','Old_Land_use_code'],as_index = False)['Old_Land_use_code'].agg({'Num_facilities':'count'})
print(ward_past)
# Pivot the table, long to wide 
ward_past = ward_past.pivot_table(index=['Old_Land_use_code'], 
                    columns='WARD_ID', 
                    values='Num_facilities')
ward_past = ward_past.fillna(0)
# Out:
#      WARD_ID                    Old_Land_use_code  Num_facilities
# 0          0                               Alleys            7167
# 1          0                           Commercial              35
# 2          0                           Industrial              14
# 3          0               Low Densit Residential               5
# 4          0                               Median            1588
# ..       ...                                  ...             ...
# 131        8   Public, Quasi-Public, Insitutional             142
# 132        8                                Roads             150
# 133        8  Transport, Communication, Utilities               3
# 134        8                         Undetermined             775
# 135        8                                Water              15
#
# [136 rows x 3 columns]

# %%
# Past land use in different Ward
pd.DataFrame(ward_past).to_csv("ward_past.csv", index=False)
ward_past
# Out:
# WARD_ID                                 0   1    2    3    4    5    6    7  \
# Old_Land_use_code
# Alleys                               7167 256  325  431  630  555  443  562
# Commercial                             35 465 1088  220  338  348  742  213
# High Density Residential                0  97   86   58   27   14   33   10
# Industrial                             14  28   36    2   19   71   96   13
# Low Densit Residential                  5  86  217 1408 1209  776   89 1655
# Low-Medium Density Residential          0 714  843  535 1082 1119 1081 1181
# Median                               1588   4   34   65   17   29   41   16
# Medium Density Residential             12 324  401  141  167  175  240  404
# Mixed Use                               0   1    8    6    0    0    1    0
# Parking                                 3   0    3    0    0    0    2    0
# Parks and Open Spaces                1253  71  212  140  105   95  166  163
# Public, Quasi-Public, Insitutional    275 167  365  146  194  203  266  197
# Roads                                 338  56  188  272  165  176  209  142
# TRAFFICIS                               8   0    0    0    0    0    4    0
# Transporation Right of Way              7   1    0    0   12    0    2    0
# Transport, Communication, Utilities    73   2    5    0   38  207   10    2
# Undetermined                        10949 264  400  508  394  680  580 1758
# Water                                 199   1   38    9    3    7   19   40
#
# WARD_ID                               8
# Old_Land_use_code
# Alleys                              258
# Commercial                          169
# High Density Residential             14
# Industrial                            7
# Low Densit Residential              507
# Low-Medium Density Residential      774
# Median                               32
# Medium Density Residential          366
# Mixed Use                             0
# Parking                               0
# Parks and Open Spaces                91
# Public, Quasi-Public, Insitutional  142
# Roads                               150
# TRAFFICIS                             0
# Transporation Right of Way            0
# Transport, Communication, Utilities   3
# Undetermined                        775
# Water                                15

# %% [markdown]
# #### By using these two data frames, we can get an insight into the trend of different Wards.

# %% [markdown]
# ### 3: Calulate the area used for different facilities

# %%
area_cal = df2.drop(columns = ['WARD_ID','SHAPE_Length'])
area_cal
# Out:
#                     Land_use_code      Old_Land_use_code  SHAPE_Area
# 0      Medium Density Residential             Commercial        4489
# 1                      Commercial             Commercial        4207
# 2                      Commercial             Commercial        2011
# 3      Transporation Right of Way  Parks and Open Spaces         410
# 4           Parks and Open Spaces  Parks and Open Spaces       49140
# ...                           ...                    ...         ...
# 55244                   Mixed Use             Commercial        6784
# 55245                  Commercial           Undetermined        2522
# 55246                  Commercial             Commercial        1662
# 55247              Federal Public             Commercial        8352
# 55248              Federal Public             Commercial       28857
#
# [55249 rows x 3 columns]

# %%
area_curr=area_cal.groupby(['Land_use_code'],as_index = False)['SHAPE_Area'].agg({'Total_Area':'sum'})
pd.DataFrame(area_curr).to_csv("area_curr.csv", index=False)
area_curr
# Out:
#                           Land_use_code  Total_Area
# 0                                Alleys     3001974
# 1                            Commercial     7930983
# 2                        Federal Public    11525231
# 3              High Density Residential     1667317
# 4                            Industrial     1710617
# 5                         Institutional     8862328
# 6                          Local Police     4918155
# 7                Low Densit Residential    20900585
# 8        Low-Medium Density Residential    16086286
# 9                                Median      455544
# 10           Medium Density Residential     7734056
# 11                            Mixed Use      379944
# 12                              Parking      247995
# 13                Parks and Open Spaces    32359765
# 14   Public, Quasi-Public, Insitutional      351655
# 15                                Roads    20092690
# 16                            TRAFFICIS        2951
# 17           Transporation Right of Way    17063026
# 18  Transport, Communication, Utilities     3480613
# 19                         Undetermined      194467
# 20                                Water    18498046

# %%
area_past=area_cal.groupby(['Old_Land_use_code'],as_index = False)['SHAPE_Area'].agg({'Total_Area':'sum'})
pd.DataFrame(area_past).to_csv("area_past.csv", index=False)
area_past
# Out:
#                       Old_Land_use_code  Total_Area
# 0                                Alleys     3001567
# 1                            Commercial     7589726
# 2              High Density Residential     1363997
# 3                            Industrial     1208054
# 4                Low Densit Residential    19560636
# 5        Low-Medium Density Residential    15395849
# 6                                Median      454439
# 7            Medium Density Residential     7634818
# 8                             Mixed Use       97662
# 9                               Parking       78744
# 10                Parks and Open Spaces    29750683
# 11   Public, Quasi-Public, Insitutional    24906131
# 12                                Roads    20092638
# 13                            TRAFFICIS        2951
# 14           Transporation Right of Way       22166
# 15  Transport, Communication, Utilities     5327613
# 16                         Undetermined    22478506
# 17                                Water    18498046

# %% [markdown]
# #### We can compare the area size used in different facilities at different times.

# %% [markdown]
# ### Visualization
# #### Because presenting the visualization in the python file has many limitations, all the visualization will be presented by Tableau.
# #### Tableau URL: https://public.tableau.com/profile/tianyi.li4471#!/vizhome/447Final/1_1?publish=yes

# %% [markdown]
# ## Explore trend in redevelopment plans

# %% [markdown]
# ### Data Source: https://opendata.dc.gov/datasets/wdcep-development-report

# %%
#import dataset
report = pd.read_csv("WDCEP_Development_Report.csv")
report
# Out:
#      OBJECTID                      PROJECTNAME  \
# 0          81                 The Wharf (Ph I)
# 1          82  ART Place at Fort Totten (Ph I)
# 2          83                         AVA NoMa
# 3          84                           Apollo
# 4          85               Shapiro Residences
# ..        ...                              ...
# 416       417                   Armature Works
# 417       418                       Barry Farm
# 418       419                      Storey Park
# 419       420                  500 Penn Street
# 420       421                    The Lady Bird
#
#                                      LOCATION  WARD  \
# 0                        Southwest Waterfront     6
# 1                  5180 South Dakota Ave., NE     5
# 2                                55 M St., NE     6
# 3                               610 H St., NE     6
# 4                            1270 4th St., NE     5
# ..                                        ...   ...
# 416                          1200 3rd St., NE     6
# 417  Martin L. King Jr. Ave. & Summer Rd., SE     8
# 418                          1005 1st St., NE     6
# 419                          500 Penn St., NE     5
# 420                         4330 48th St., NW     3
#
#                                              DEVELOPER  \
# 0                           Hoffman-Madison Waterfront
# 1                Morris & Gwendolyn Cafritz Foundation
# 2                                            AvalonBay
# 3                               Insight Property Group
# 4                          Level 2 Development / EDENS
# ..                                                 ...
# 416  Trammell Crow Company / High Street Residentia...
# 417  Preservation of Affordable Housing / A&R Devel...
# 418  Four Points / Perseus Realty / Buccini Pollin ...
# 419                                        EDENS / UDR
# 420                                  Valor Development
#
#                                              ARCHITECT              STATUS  \
# 0    BBGM / Handel Architects / FOX Architects / Ko...  Under Construction
# 1    EE&K / MV+A Architects / Shalom Baranes Associ...  Under Construction
# 2                                      KTGY Group, Inc  Under Construction
# 3                      SK+I Architectural Design Group  Under Construction
# 4                            Shalom Baranes Associates  Under Construction
# ..                                                 ...                 ...
# 416                                                NaN            Pipeline
# 417                                                NaN            Pipeline
# 418                                                NaN            Pipeline
# 419                                                NaN            Pipeline
# 420                                                NaN            Pipeline
#
#      UNITS   TYPE     SQFT  ESTVALUEINMILION ESTDELIVERY  PROJECTTYPE
# 0    870.0  R / O      NaN            1200.0       Q4 17  RESIDENTIAL
# 1    520.0      R      NaN             125.0       Q2 17  RESIDENTIAL
# 2    438.0      R      NaN             145.0       Q1 17  RESIDENTIAL
# 3    431.0      R      NaN             195.0       Q4 16  RESIDENTIAL
# 4    430.0      R      NaN             150.0       Q4 18  RESIDENTIAL
# ..     ...    ...      ...               ...         ...          ...
# 416    NaN    NaN  60000.0       400000000.0        2022       RETAIL
# 417    NaN    NaN  50000.0       500000000.0        2021       RETAIL
# 418    NaN    NaN  27313.0       330000000.0        2022       RETAIL
# 419    NaN    NaN  22714.0       150000000.0        2022       RETAIL
# 420    NaN    NaN  16500.0       127000000.0        2022       RETAIL
#
# [421 rows x 13 columns]

# %%
# Cleaning the csv file
cleaned = report.drop(columns = ['OBJECTID','PROJECTNAME','LOCATION','DEVELOPER','ARCHITECT','TYPE','ESTDELIVERY'])
cleaned1 = cleaned.rename(columns = {"ESTVALUEINMILION": "Value_In_Million", "SQFT":"Square_Foot"})
cleaned1
# Out:
#      WARD              STATUS  UNITS  Square_Foot  Value_In_Million  \
# 0       6  Under Construction  870.0          NaN            1200.0
# 1       5  Under Construction  520.0          NaN             125.0
# 2       6  Under Construction  438.0          NaN             145.0
# 3       6  Under Construction  431.0          NaN             195.0
# 4       5  Under Construction  430.0          NaN             150.0
# ..    ...                 ...    ...          ...               ...
# 416     6            Pipeline    NaN      60000.0       400000000.0
# 417     8            Pipeline    NaN      50000.0       500000000.0
# 418     6            Pipeline    NaN      27313.0       330000000.0
# 419     5            Pipeline    NaN      22714.0       150000000.0
# 420     3            Pipeline    NaN      16500.0       127000000.0
#
#      PROJECTTYPE
# 0    RESIDENTIAL
# 1    RESIDENTIAL
# 2    RESIDENTIAL
# 3    RESIDENTIAL
# 4    RESIDENTIAL
# ..           ...
# 416       RETAIL
# 417       RETAIL
# 418       RETAIL
# 419       RETAIL
# 420       RETAIL
#
# [421 rows x 6 columns]

# %%
#save cleaned dataset into a csv file
pd.DataFrame(cleaned1).to_csv("WDCEP_Cleaned.csv", index = False)

# %%
#get the counts of Ward, Status, and Project type
print(cleaned1['WARD'].value_counts())
print('\n')
print(cleaned1['STATUS'].value_counts())
print('\n')
print(cleaned1['PROJECTTYPE'].value_counts())
# Out:
# 6    170
# 2    107
# 5     47
# 1     25
# 8     22
# 3     21
# 7     15
# 4     14
# Name: WARD, dtype: int64
#
#
# Completed             141
# Under Construction    140
# Pipeline              140
# Name: STATUS, dtype: int64
#
#
# OFFICE             91
# RETAIL             90
# HOSPITALITY        90
# RESIDENTIAL        90
# QUALITY OF LIFE    30
# EDUCATION          30
# Name: PROJECTTYPE, dtype: int64

# %%
#rename status types
cleaned1['STATUS'] = cleaned1['STATUS'].replace(['Completed'],'Old Land')
cleaned1['STATUS'] = cleaned1['STATUS'].replace(['Under Construction'],'New Land')
cleaned1['STATUS'] = cleaned1['STATUS'].replace(['Pipeline'],'Future Land')
cleaned1
# Out:
#      WARD       STATUS  UNITS  Square_Foot  Value_In_Million  PROJECTTYPE
# 0       6     New Land  870.0          NaN            1200.0  RESIDENTIAL
# 1       5     New Land  520.0          NaN             125.0  RESIDENTIAL
# 2       6     New Land  438.0          NaN             145.0  RESIDENTIAL
# 3       6     New Land  431.0          NaN             195.0  RESIDENTIAL
# 4       5     New Land  430.0          NaN             150.0  RESIDENTIAL
# ..    ...          ...    ...          ...               ...          ...
# 416     6  Future Land    NaN      60000.0       400000000.0       RETAIL
# 417     8  Future Land    NaN      50000.0       500000000.0       RETAIL
# 418     6  Future Land    NaN      27313.0       330000000.0       RETAIL
# 419     5  Future Land    NaN      22714.0       150000000.0       RETAIL
# 420     3  Future Land    NaN      16500.0       127000000.0       RETAIL
#
# [421 rows x 6 columns]

# %%
#save cleaned dataset into a csv file
pd.DataFrame(cleaned1).to_csv("land_compare.csv", index = False)

# %%
#remove unnecessary columns
cleaned2 = cleaned1.drop(columns = ['WARD','UNITS','Value_In_Million','PROJECTTYPE'])
cleaned2
# Out:
#           STATUS  Square_Foot
# 0       New Land          NaN
# 1       New Land          NaN
# 2       New Land          NaN
# 3       New Land          NaN
# 4       New Land          NaN
# ..           ...          ...
# 416  Future Land      60000.0
# 417  Future Land      50000.0
# 418  Future Land      27313.0
# 419  Future Land      22714.0
# 420  Future Land      16500.0
#
# [421 rows x 2 columns]

# %%
#replace N/A values with 0
cleaned2['Square_Foot'] = cleaned2['Square_Foot'].replace(np.nan,0)
cleaned2
# Out:
#           STATUS  Square_Foot
# 0       New Land          0.0
# 1       New Land          0.0
# 2       New Land          0.0
# 3       New Land          0.0
# 4       New Land          0.0
# ..           ...          ...
# 416  Future Land      60000.0
# 417  Future Land      50000.0
# 418  Future Land      27313.0
# 419  Future Land      22714.0
# 420  Future Land      16500.0
#
# [421 rows x 2 columns]

# %%
#Find the sum of total land area for each project status
area_count = cleaned2.groupby(['STATUS'],as_index = False)['Square_Foot'].agg({'Total_Area_In_sqft':'sum'})
area_count
# Out:
#         STATUS  Total_Area_In_sqft
# 0  Future Land          18526928.0
# 1     New Land          24799911.0
# 2     Old Land          18181563.0

# %%
#save area count from above into a csv file
pd.DataFrame(area_count).to_csv("area_count.csv", index = False)

# %% [markdown]
# ### Data Visualization from Tableau
#
# https://public.tableau.com/profile/ruiqi.lai#!/vizhome/Storycomapre/Story1?publish=yes

# %% [markdown]
# ## Affordable Housing in DC

# %% [markdown]
# ### Data source: https://opendata.dc.gov/datasets/affordable-housing

# %%
#read in data set
house = pd.read_csv('Affordable_Housing.csv')
house
# Out:
#              X          Y  OBJECTID  WARD  \
# 0   -76.990877  38.899991         2     6
# 1   -77.024192  38.906944         4     2
# 2   -76.987587  38.878612         5     6
# 3   -77.032337  38.908296         6     2
# 4   -76.985771  38.899616         8     6
# ..         ...        ...       ...   ...
# 514 -77.027820  38.931142      1694     1
# 515 -76.916181  38.897397      1695     7
# 516 -76.965060  38.858933      1696     7
# 517 -77.034396  38.924330      1697     1
# 518 -77.032996  38.912364      1698     2
#
#                                                ADDRESS  \
# 0    1115 H St NE, Washington, District of Columbia...
# 1    1250 9th St NW, Washington, District of Columb...
# 2    1314 K St SE, Washington, District of Columbia...
# 3    1328 14th St NW, Washington, District of Colum...
# 4    1350 Maryland Ave NE, Washington, District of ...
# ..                                                 ...
# 514  3315 11th Street Northwest, Washington, Distri...
# 515  5900 Foote Street Northeast, Washington, Distr...
# 516  2604 29th Street Southeast, Washington, Distri...
# 517  2622 University Place Northwest, Washington, D...
# 518  1420 R Street Northwest, Washington, District ...
#
#                            PROJECT_NAME           STATUS_PUBLIC  \
# 0    1115 H Street NE (Woolworth Condo)  Completed 2015 to Date
# 1                           The Colonel  Completed 2015 to Date
# 2          1314 K Street SE Cooperative  Completed 2015 to Date
# 3                           The Bentley  Completed 2015 to Date
# 4                          The Maryland  Completed 2015 to Date
# ..                                  ...                     ...
# 514                     3315 11th St NW                Pipeline
# 515                    5900 Foote St NE                Pipeline
# 516                     2604 29th St SE                Pipeline
# 517             University Place Condos                Pipeline
# 518              Ritch Homes Apartments                Pipeline
#
#     AGENCY_CALCULATED  TOTAL_AFFORDABLE_UNITS   LATITUDE  ...  \
# 0          DMPED DHCD                       4  38.899951  ...
# 1                DHCD                       6  38.906937  ...
# 2                DHCD                      12  38.878605  ...
# 3                DHCD                       4  38.908300  ...
# 4                DHCD                       7  38.899464  ...
# ..                ...                     ...        ...  ...
# 514              DHCD                       0  38.931135  ...
# 515              DHCD                       0  38.897389  ...
# 516              DHCD                       0  38.858925  ...
# 517              DHCD                       0  38.924322  ...
# 518        DCHFA DHCD                       0  38.912357  ...
#
#      AFFORDABLE_UNITS_AT_31_50_AMI  AFFORDABLE_UNITS_AT_51_60_AMI  \
# 0                                2                              0
# 1                                3                              0
# 2                                0                              0
# 3                                0                              0
# 4                                0                              0
# ..                             ...                            ...
# 514                              0                              0
# 515                              0                              0
# 516                              0                              0
# 517                              0                              0
# 518                              0                              0
#
#      AFFORDABLE_UNITS_AT_61_80_AMI  AFFORDABLE_UNITS_AT_81_AMI  CASE_ID  \
# 0                                2                           0      NaN
# 1                                3                           0      NaN
# 2                               12                           0      NaN
# 3                                4                           0      NaN
# 4                                7                           0      NaN
# ..                             ...                         ...      ...
# 514                              0                           0      NaN
# 515                              0                           0      NaN
# 516                              0                           0      NaN
# 517                              0                           0      NaN
# 518                              0                           0      NaN
#
#      ADDRESS_ID         XCOORD         YCOORD               FULLADDRESS  \
# 0      311081.0  400791.550000  136903.510000          1115 H STREET NE
# 1      239786.0  397901.890000  137675.560000        1250 9TH STREET NW
# 2       68283.0  401077.270000  134530.310000          1314 K STREET SE
# 3      279073.0  397195.500000  137825.850000       1328 14TH STREET NW
# 4      149108.0  401234.470000  136861.930000   1350 MARYLAND AVENUE NE
# ..          ...            ...            ...                       ...
# 514    230987.0  397588.060000  140361.870000       3315 11TH STREET NW
# 515         NaN  407271.279859  136618.786787                       NaN
# 516     45976.0  403032.740000  132346.260000       2604 29TH STREET SE
# 517    234284.0  397017.570000  139605.800000  2622 UNIVERSITY PLACE NW
# 518    240186.0  397138.480000  138277.500000          1420 R STREET NW
#
#           GIS_LAST_MOD_DTTM
# 0    2020/11/30 04:00:39+00
# 1    2020/11/30 04:00:39+00
# 2    2020/11/30 04:00:39+00
# 3    2020/11/30 04:00:39+00
# 4    2020/11/30 04:00:39+00
# ..                      ...
# 514  2020/11/30 04:00:39+00
# 515  2020/11/30 04:00:39+00
# 516  2020/11/30 04:00:39+00
# 517  2020/11/30 04:00:39+00
# 518  2020/11/30 04:00:39+00
#
# [519 rows x 22 columns]

# %%
#drop na values
cleanedhouse = house.dropna()
cleanedhouse
# Out:
#              X          Y  OBJECTID  WARD  \
# 21  -76.926824  38.899416        53     7
# 28  -77.023189  38.908253        65     6
# 30  -76.989519  38.839932        70     8
# 51  -76.951506  38.924894       123     5
# 53  -77.000549  38.907486       127     5
# ..         ...        ...       ...   ...
# 386 -76.996410  38.928350      1553     5
# 438 -77.095042  38.945749      1613     3
# 440 -77.019563  38.905895      1615     6
# 441 -76.971573  38.848453      1616     8
# 449 -76.997927  38.910897      1624     5
#
#                                                ADDRESS  \
# 21   5201 Hayes Street Northeast, Washington, Distr...
# 28   1336 8th St NW, Washington, District of Columb...
# 30   1200 Mississippi Ave SE, Washington, District ...
# 51   3750 Jamison St NE, Washington, District of Co...
# 53   340 Florida Avenue Northeast, Washington, Dist...
# ..                                                 ...
# 386  3058 7th Street Northeast, Washington, Distric...
# 438  4330 48th Street Northwest, Washington, Distri...
# 440  1200 5th Street Northwest, Washington, Distric...
# 441  3301 23rd Street Southeast, Washington, Distri...
# 449  401 New York Avenue Northeast, Washington, Dis...
#
#                                       PROJECT_NAME           STATUS_PUBLIC  \
# 21              5201 Hayes Street (Deanwood Hills)  Completed 2015 to Date
# 28                                 8th/O Street NW                Pipeline
# 30                            Archer Park (Wing I)  Completed 2015 to Date
# 51                        Fort Lincoln Multifamily  Completed 2015 to Date
# 53                      The Edison at Union Market  Completed 2015 to Date
# ..                                             ...                     ...
# 386                                Portrait Square  Completed 2015 to Date
# 438  48th Street and Yuma Street NW, Spring Valley                Pipeline
# 440                                 1200 5th St NW                Pipeline
# 441                                3301 23rd St SE                Pipeline
# 449              401 New York Ave & 1348 4th St NE                Pipeline
#
#        AGENCY_CALCULATED  TOTAL_AFFORDABLE_UNITS   LATITUDE  ...  \
# 21   DMPED DCHFA DHCD OP                     150  38.899381  ...
# 28              DMPED OP                      23  38.908245  ...
# 30         DCHFA DHCD OP                     190  38.840055  ...
# 51         DMPED DHCD OP                      36  38.928471  ...
# 53              DMPED OP                      38  38.907564  ...
# ..                   ...                     ...        ...  ...
# 386              DHCD OP                       3  38.928342  ...
# 438                   OP                      30  38.945742  ...
# 440                   OP                      41  38.905887  ...
# 441                   OP                     130  38.848445  ...
# 449                   OP                      37  38.910889  ...
#
#      AFFORDABLE_UNITS_AT_31_50_AMI  AFFORDABLE_UNITS_AT_51_60_AMI  \
# 21                              10                            100
# 28                              11                              0
# 30                               0                            180
# 51                              18                              0
# 53                               0                              0
# ..                             ...                            ...
# 386                              2                              0
# 438                              0                             30
# 440                              0                             41
# 441                              0                            130
# 449                              0                             37
#
#      AFFORDABLE_UNITS_AT_61_80_AMI  AFFORDABLE_UNITS_AT_81_AMI  CASE_ID  \
# 21                               0                           0    15-10
# 28                              12                           0    16-24
# 30                               0                           0    13-17
# 51                              18                           0    06-08
# 53                              38                           0   06-40C
# ..                             ...                         ...      ...
# 386                              1                           0    15-02
# 438                              0                           0    19-10
# 440                              0                           0    19-16
# 441                              0                           0    19-19
# 449                              0                           0    19-29
#
#      ADDRESS_ID     XCOORD     YCOORD                 FULLADDRESS  \
# 21     299817.0  406347.86  136842.14        5201 HAYES STREET NE
# 28     319628.0  397988.89  137820.85          1336 8TH STREET NW
# 30     296061.0  400910.09  130236.53  1200 MISSISSIPPI AVENUE SE
# 51     314268.0  404205.28  139668.95      3750 JAMISON STREET NE
# 53     287853.0  399952.55  137735.41       340 FLORIDA AVENUE NE
# ..          ...        ...        ...                         ...
# 386    317725.0  400311.51  140051.53          3058 7TH STREET NE
# 438    269574.0  391761.15  141987.30         4330 48TH STREET NW
# 440    296060.0  398303.41  137558.98          1200 5TH STREET NW
# 441    319271.0  402467.82  131182.69         3301 23RD STREET SE
# 449    302556.0  400180.00  138114.04      401 NEW YORK AVENUE NE
#
#           GIS_LAST_MOD_DTTM
# 21   2020/11/30 04:00:39+00
# 28   2020/11/30 04:00:39+00
# 30   2020/11/30 04:00:39+00
# 51   2020/11/30 04:00:39+00
# 53   2020/11/30 04:00:39+00
# ..                      ...
# 386  2020/11/30 04:00:39+00
# 438  2020/11/30 04:00:39+00
# 440  2020/11/30 04:00:39+00
# 441  2020/11/30 04:00:39+00
# 449  2020/11/30 04:00:39+00
#
# [76 rows x 22 columns]

# %%
# put cleaned dataframe into a .csv file 
pd.DataFrame(cleanedhouse).to_csv("Affordable_Housing_cleaned.csv", index=False)

# %%
#aggregate to get the sum of the number of affordable units for each development status
statusaff = cleanedhouse[['STATUS_PUBLIC','TOTAL_AFFORDABLE_UNITS']].groupby(['STATUS_PUBLIC'], as_index=False).agg('sum')
statusaff.columns = ['Status','Total Affordable Units'] #rename column
statusaff
# Out:
#                    Status  Total Affordable Units
# 0  Completed 2015 to Date                    1559
# 1                Pipeline                    1698
# 2      Under Construction                     727

# %%
#aggregate to get the sum of the number of affordable units per ward and put into df
waffs = cleanedhouse[['WARD','TOTAL_AFFORDABLE_UNITS']].groupby(['WARD'], as_index=False).agg('sum')
waffs.columns = ["WARD", "Total Affordable Units"] #rename column
waffs
# Out:
#    WARD  Total Affordable Units
# 0     1                     670
# 1     2                     150
# 2     3                      84
# 3     5                     737
# 4     6                    1197
# 5     7                     721
# 6     8                     425

# %%
#create a bar graph of the number of affordable units for each development status
plt.bar(statusaff['Status'], statusaff['Total Affordable Units'], color='blue')
plt.title("Total Number of Affordable Units Per Status")
plt.xlabel("Statuses")
plt.ylabel("Number of Affordable Units")
plt.show()

# %%
#create a bar graph of the number of affordable units for each ward
plt.bar(waffs['WARD'], waffs['Total Affordable Units'], color='green')
plt.title("Number of Affordable Units Per Ward")
plt.xlabel("Wards")
plt.ylabel("Number of Affordable Units")
plt.show()

# %% [markdown]
# ##### Merge Affordable Housing Dataset with Redevelopment Plans Dataset

# %%
#take cleaned WDCEP development plans dataset and retrieve necessary columns and put into df
plans = cleaned1[['WARD','UNITS']]
cleanedplans = plans.dropna() #drop na values
cleanedplans
# Out:
#      WARD  UNITS
# 0       6  870.0
# 1       5  520.0
# 2       6  438.0
# 3       6  431.0
# 4       5  430.0
# ..    ...    ...
# 386     6  472.0
# 387     6  456.0
# 388     1  450.0
# 389     6  425.0
# 390     6  363.0
#
# [148 rows x 2 columns]

# %%
#aggregate to get the sum of developed/developing units per ward and put into df
devunits = cleanedplans[['WARD','UNITS']].groupby(['WARD'], as_index=False).agg('sum')
devunits
# Out:
#    WARD    UNITS
# 0     1   3901.0
# 1     2   6060.0
# 2     3   2711.0
# 3     4    735.0
# 4     5   8817.0
# 5     6  29089.0
# 6     7    353.0
# 7     8    615.0

# %%
#merge the devunits with the affordable housing per ward df from earlier (waffs)
dfx = pd.merge(devunits,waffs,how="outer",on="WARD")
dfx.fillna(0)
# Out:
#    WARD    UNITS  Total Affordable Units
# 0     1   3901.0                   670.0
# 1     2   6060.0                   150.0
# 2     3   2711.0                    84.0
# 3     4    735.0                     0.0
# 4     5   8817.0                   737.0
# 5     6  29089.0                  1197.0
# 6     7    353.0                   721.0
# 7     8    615.0                   425.0

# %%
#plot of developing units and affordable housing units per ward on separate graphs
fig, axs = plt.subplots(2)
dfx['WARD'], dfx['Total Affordable Units'].plot.bar(
    ax=axs[0], title='Affordable Units per Ward')
dfx['WARD'], dfx['UNITS'].plot.bar(
    ax=axs[1], title='Develop Units per Ward')
plt.xlabel('Ward')
plt.subplots_adjust(hspace = 0.5)#space between plots

# %%
#plot of developing units and affordable housing units per ward on one graph
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(dfx['WARD'], dfx['Total Affordable Units'], color="red", marker="o")
# set x-axis label
ax.set_xlabel("Wards",fontsize=14)
# set y-axis label
ax.set_ylabel("Total Number of Afforable Units",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(dfx['WARD'], dfx['UNITS'],color="blue",marker="o")
ax2.set_ylabel("Total Number of Developing/Developed Units",color="blue",fontsize=14)
plt.title("# of Affordable Units VS # of Developing/Developed Units Per Ward")
plt.show()

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### *A synopsis of what you found in your analysis (e.g. did your expected outcome change based on the data, did you have enough data to answer your research question). Think graphs or anything else to make your point about the analysis.*

# %% [markdown]
# ## What would you do differently if you had the time?

# %% [markdown]
# ###

# %% [markdown]
# ## Are there any additional data sources that you would like to integrate?

# %% [markdown]
# ###
